# %%
# !pip install mne
# !pip install tensorflow
# !pip install pyriemann
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mne
#   Downloading mne-1.0.3-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 26.5 MB/s
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from mne) (1.21.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne) (2.11.3)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne) (21.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from mne) (3.2.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from mne) (1.4.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne) (4.64.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (1.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->mne) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->mne) (1.15.0)
# Installing collected packages: mne
# Successfully installed mne-1.0.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyriemann
#   Downloading pyriemann-0.2.7.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyriemann) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyriemann) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pyriemann) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyriemann) (3.1.0)
# Building wheels for collected packages: pyriemann
#   Building wheel for pyriemann (setup.py) ... done
#   Created wheel for pyriemann: filename=pyriemann-0.2.7-py2.py3-none-any.whl size=49770 sha256=a97692e806270cbd2abc26500acb91be98d9d3cb5ee1e6d0aeab761145b45c3a
#   Stored in directory: /root/.cache/pip/wheels/5c/b7/55/27dcb08ed8fb58da8c1be108c23928ffb9125c9c1da2ddfb53
# Successfully built pyriemann
# Installing collected packages: pyriemann
# Successfully installed pyriemann-0.2.7

# %%
import numpy as np
import os
import tensorflow

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.utils.viz import plot_confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

from sklearn.utils import shuffle

# %%
def EEGNet(nb_classes, Chans = 22, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    
    While the original paper used Dropout, we found that SpatialDropout2D 
    sometimes produced slightly better results for classification of ERP 
    signals. However, SpatialDropout2D significantly reduced performance 
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 
    
    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)




def EEGNet_SSVEP(nb_classes = 12, Chans = 8, Samples = 256, 
             dropoutRate = 0.5, kernLength = 256, F1 = 96, 
             D = 1, F2 = 96, dropoutType = 'Dropout'):
    """ SSVEP Variant of EEGNet, as used in [1]. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. 
      D               : number of spatial filters to learn within each temporal
                        convolution.
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.
      
      
    [1]. Waytowich, N. et. al. (2018). Compact Convolutional Neural Networks
    for Classification of Asynchronous Steady-State Visual Evoked Potentials.
    Journal of Neural Engineering vol. 15(6). 
    http://iopscience.iop.org/article/10.1088/1741-2552/aae5d8

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)



def EEGNet_old(nb_classes, Chans = 64, Samples = 128, regRate = 0.0001,
           dropoutRate = 0.25, kernels = [(2, 32), (8, 4)], strides = (2, 4)):
    """ Keras Implementation of EEGNet_v1 (https://arxiv.org/abs/1611.08024v2)

    This model is the original EEGNet model proposed on arxiv
            https://arxiv.org/abs/1611.08024v2
    
    with a few modifications: we use striding instead of max-pooling as this 
    helped slightly in classification performance while also providing a 
    computational speed-up. 
    
    Note that we no longer recommend the use of this architecture, as the new
    version of EEGNet performs much better overall and has nicer properties.
    
    Inputs:
        
        nb_classes     : total number of final categories
        Chans, Samples : number of EEG channels and samples, respectively
        regRate        : regularization rate for L1 and L2 regularizations
        dropoutRate    : dropout fraction
        kernels        : the 2nd and 3rd layer kernel dimensions (default is 
                         the [2, 32] x [8, 4] configuration)
        strides        : the stride size (note that this replaces the max-pool
                         used in the original paper)
    
    """

    # start the model
    input_main   = Input((Chans, Samples))
    layer1       = Conv2D(16, (Chans, 1), input_shape=(Chans, Samples, 1),
                                 kernel_regularizer = l1_l2(l1=regRate, l2=regRate))(input_main)
    layer1       = BatchNormalization()(layer1)
    layer1       = Activation('elu')(layer1)
    layer1       = Dropout(dropoutRate)(layer1)
    
    permute_dims = 2, 1, 3
    permute1     = Permute(permute_dims)(layer1)
    
    layer2       = Conv2D(4, kernels[0], padding = 'same', 
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(permute1)
    layer2       = BatchNormalization()(layer2)
    layer2       = Activation('elu')(layer2)
    layer2       = Dropout(dropoutRate)(layer2)
    
    layer3       = Conv2D(4, kernels[1], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(layer2)
    layer3       = BatchNormalization()(layer3)
    layer3       = Activation('elu')(layer3)
    layer3       = Dropout(dropoutRate)(layer3)
    
    flatten      = Flatten(name = 'flatten')(layer3)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)



def DeepConvNet(nb_classes, Chans = 64, Samples = 256,
                dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.
    
    This implementation assumes the input is a 2-second EEG signal sampled at 
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference. 
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10
    
    Note that this implementation has not been verified by the original 
    authors. 
    
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)


# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 64, Samples = 128, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path_string = '/content/drive/MyDrive/BCICIV_2a_gdf/'



filenames = [ "A01T.gdf", 'A02T.gdf', 'A03T.gdf', 'A05T.gdf', 'A06T.gdf', 'A07T.gdf', 'A08T.gdf', 'A09T.gdf']
#filenames = [ "A01T.gdf", 'A02T.gdf', 'A03T.gdf', 'A05T.gdf', 'A06T.gdf', 'A07T.gdf', 'A08T.gdf', 'A09T.gdf',
#              "A01E.gdf", 'A02E.gdf', 'A03E.gdf', 'A05E.gdf', 'A06E.gdf', 'A07E.gdf', 'A08E.gdf', 'A09E.gdf']
raws = []

for filename in filenames:
    path = folder_path_string + filename
    raws.append(mne.io.read_raw_gdf(path))
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A02T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A03T.gdf...
# GDF file detected
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A05T.gdf...
# GDF file detected
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A06T.gdf...
# GDF file detected
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A07T.gdf...
# GDF file detected
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A08T.gdf...
# GDF file detected
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A09T.gdf...
# GDF file detected
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)

# %%
#set seed
tensorflow.random.set_seed(1234)

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
tmin, tmax = -0., 1

counter = 1
for raw in raws:

    raw.load_data()


    #new filter 

    #iir_params = dict(order=3, ftype='butter', sfreq = 250, output='sos', btype='highpass')
    #raw.filter(2,None, method='iir', iir_params=iir_params) 
    
    #original filter
    raw.filter(2, None, method='iir')  # replace baselining with high-pass


    events = mne.events_from_annotations(raw)

    event_id = events[1]
    #print("event_id ",event_id)

    raw.info['bads'] = ['EOG-left', 'EOG-central', 'EOG-right']  # set bad channels
    picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                           exclude='bads')

    # Read epochs
    stims =[value for key, value in event_id.items() if key in ('769','770','771','772')]
    epochs = mne.Epochs(raw, events[0], stims, tmin, tmax, proj=False,
                        picks=picks, baseline=None, preload=True, verbose=False)

    if counter == 1:
        X = epochs.get_data()*1000
        y = epochs.events[:, -1]
    else:
        X = np.concatenate([X, epochs.get_data()*1000])
        y = np.concatenate([y, epochs.events[:, -1]])

    counter += 1

print("X shape: ", X.shape)
print("Y shape: ", y.shape)

y[y == 7] = 0
y[y == 8] = 1
y[y == 9] = 2
y[y == 10] = 3

kernels, chans, samples = 1, X.shape[1], X.shape[2]
print("chans: ", chans)
print("samples: ", samples)

train_index = int(X.shape[0] * 0.8)
test_index = int(X.shape[0] * 0.9)
print("train_index: ", train_index)
print("test_index: ", test_index)

# take 80/10/10 percent of the data to train/validate/test 
X, y = shuffle(X, y, random_state=0)                                ########################################### shuffling
X_train      = X[0:train_index,]
Y_train      = y[0:train_index]
X_validate   = X[train_index:test_index,]
Y_validate   = y[train_index:test_index]
X_test       = X[test_index:,]
Y_test       = y[test_index:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
y_unique = np.unique(y)
print("y_unique: ", y_unique)
num_classes = len(y_unique)
print("num_classes: ", num_classes)
Y_train      = np_utils.to_categorical(Y_train-1, num_classes=num_classes)
Y_validate   = np_utils.to_categorical(Y_validate-1, num_classes=num_classes)
Y_test       = np_utils.to_categorical(Y_test-1, num_classes=num_classes)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples,              #################### Change Model here
               dropoutRate = 0.5, kernLength = 128, F1 = 16, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy', 'TruePositives', 'TrueNegatives'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1,
                               save_best_only=True)

#fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
#                        verbose = 2, validation_data=(X_validate, Y_validate),
#                        callbacks=[checkpointer], class_weight = class_weights)

fittedModel = model.fit(X_train, Y_train, batch_size = 32, epochs = 300,
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])

# load optimal weights
model.load_weights('/tmp/checkpoint.h5')

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# X shape:  (2304, 22, 251)
# Y shape:  (2304,)
# chans:  22
# samples:  251
# train_index:  1843
# test_index:  2073
# y_unique:  [0 1 2 3]
# num_classes:  4
# X_train shape: (1843, 22, 251, 1)
# 1843 train samples
# 231 test samples
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.38591, saving model to /tmp/checkpoint.h5
# 58/58 - 14s - loss: 1.3881 - accuracy: 0.2735 - true_positives: 1.0000 - true_negatives: 5526.0000 - val_loss: 1.3859 - val_accuracy: 0.2565 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 14s/epoch - 236ms/step
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 1.38591
# 58/58 - 0s - loss: 1.3612 - accuracy: 0.3131 - true_positives: 1.0000 - true_negatives: 5529.0000 - val_loss: 1.3859 - val_accuracy: 0.2565 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 424ms/epoch - 7ms/step
# Epoch 3/300
#
# Epoch 3: val_loss improved from 1.38591 to 1.38571, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.3361 - accuracy: 0.3500 - true_positives: 20.0000 - true_negatives: 5512.0000 - val_loss: 1.3857 - val_accuracy: 0.2565 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 450ms/epoch - 8ms/step
# Epoch 4/300
#
# Epoch 4: val_loss improved from 1.38571 to 1.38568, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.3227 - accuracy: 0.3684 - true_positives: 30.0000 - true_negatives: 5513.0000 - val_loss: 1.3857 - val_accuracy: 0.2565 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 456ms/epoch - 8ms/step
# Epoch 5/300
#
# Epoch 5: val_loss improved from 1.38568 to 1.38452, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2947 - accuracy: 0.3890 - true_positives: 33.0000 - true_negatives: 5505.0000 - val_loss: 1.3845 - val_accuracy: 0.2652 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 457ms/epoch - 8ms/step
# Epoch 6/300
#
# Epoch 6: val_loss improved from 1.38452 to 1.37966, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2713 - accuracy: 0.4232 - true_positives: 69.0000 - true_negatives: 5487.0000 - val_loss: 1.3797 - val_accuracy: 0.3087 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 449ms/epoch - 8ms/step
# Epoch 7/300
#
# Epoch 7: val_loss improved from 1.37966 to 1.37302, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2768 - accuracy: 0.4010 - true_positives: 60.0000 - true_negatives: 5489.0000 - val_loss: 1.3730 - val_accuracy: 0.3087 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 451ms/epoch - 8ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.37302 to 1.35619, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2440 - accuracy: 0.4373 - true_positives: 99.0000 - true_negatives: 5476.0000 - val_loss: 1.3562 - val_accuracy: 0.3130 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 462ms/epoch - 8ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.35619 to 1.33039, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2493 - accuracy: 0.4341 - true_positives: 106.0000 - true_negatives: 5465.0000 - val_loss: 1.3304 - val_accuracy: 0.3783 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 491ms/epoch - 8ms/step
# Epoch 10/300
#
# Epoch 10: val_loss improved from 1.33039 to 1.30886, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2404 - accuracy: 0.4362 - true_positives: 112.0000 - true_negatives: 5455.0000 - val_loss: 1.3089 - val_accuracy: 0.3957 - val_true_positives: 0.0000e+00 - val_true_negatives: 690.0000 - 495ms/epoch - 9ms/step
# Epoch 11/300
#
# Epoch 11: val_loss improved from 1.30886 to 1.28658, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2222 - accuracy: 0.4520 - true_positives: 138.0000 - true_negatives: 5468.0000 - val_loss: 1.2866 - val_accuracy: 0.4043 - val_true_positives: 1.0000 - val_true_negatives: 688.0000 - 480ms/epoch - 8ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.28658 to 1.27086, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2075 - accuracy: 0.4639 - true_positives: 173.0000 - true_negatives: 5464.0000 - val_loss: 1.2709 - val_accuracy: 0.4217 - val_true_positives: 8.0000 - val_true_negatives: 688.0000 - 453ms/epoch - 8ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.27086 to 1.22155, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.2034 - accuracy: 0.4650 - true_positives: 188.0000 - true_negatives: 5442.0000 - val_loss: 1.2216 - val_accuracy: 0.4565 - val_true_positives: 11.0000 - val_true_negatives: 688.0000 - 483ms/epoch - 8ms/step
# Epoch 14/300
#
# Epoch 14: val_loss did not improve from 1.22155
# 58/58 - 0s - loss: 1.1925 - accuracy: 0.4715 - true_positives: 200.0000 - true_negatives: 5440.0000 - val_loss: 1.2346 - val_accuracy: 0.4391 - val_true_positives: 11.0000 - val_true_negatives: 684.0000 - 443ms/epoch - 8ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 1.22155 to 1.20942, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1969 - accuracy: 0.4514 - true_positives: 193.0000 - true_negatives: 5425.0000 - val_loss: 1.2094 - val_accuracy: 0.5000 - val_true_positives: 25.0000 - val_true_negatives: 686.0000 - 448ms/epoch - 8ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 1.20942 to 1.20238, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1961 - accuracy: 0.4737 - true_positives: 218.0000 - true_negatives: 5419.0000 - val_loss: 1.2024 - val_accuracy: 0.4609 - val_true_positives: 25.0000 - val_true_negatives: 682.0000 - 489ms/epoch - 8ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 1.20238 to 1.18062, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1681 - accuracy: 0.4921 - true_positives: 246.0000 - true_negatives: 5433.0000 - val_loss: 1.1806 - val_accuracy: 0.4870 - val_true_positives: 33.0000 - val_true_negatives: 682.0000 - 488ms/epoch - 8ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 1.18062
# 58/58 - 0s - loss: 1.1756 - accuracy: 0.4786 - true_positives: 241.0000 - true_negatives: 5411.0000 - val_loss: 1.1829 - val_accuracy: 0.4870 - val_true_positives: 34.0000 - val_true_negatives: 681.0000 - 418ms/epoch - 7ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 1.18062 to 1.17045, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1712 - accuracy: 0.4775 - true_positives: 257.0000 - true_negatives: 5411.0000 - val_loss: 1.1704 - val_accuracy: 0.4870 - val_true_positives: 42.0000 - val_true_negatives: 673.0000 - 484ms/epoch - 8ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 1.17045 to 1.16721, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1553 - accuracy: 0.5019 - true_positives: 301.0000 - true_negatives: 5410.0000 - val_loss: 1.1672 - val_accuracy: 0.4913 - val_true_positives: 34.0000 - val_true_negatives: 682.0000 - 447ms/epoch - 8ms/step
# Epoch 21/300
#
# Epoch 21: val_loss did not improve from 1.16721
# 58/58 - 0s - loss: 1.1611 - accuracy: 0.4818 - true_positives: 292.0000 - true_negatives: 5393.0000 - val_loss: 1.1789 - val_accuracy: 0.4870 - val_true_positives: 42.0000 - val_true_negatives: 673.0000 - 442ms/epoch - 8ms/step
# Epoch 22/300
#
# Epoch 22: val_loss improved from 1.16721 to 1.16091, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1565 - accuracy: 0.4921 - true_positives: 287.0000 - true_negatives: 5395.0000 - val_loss: 1.1609 - val_accuracy: 0.5130 - val_true_positives: 39.0000 - val_true_negatives: 676.0000 - 485ms/epoch - 8ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 1.16091 to 1.15931, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1511 - accuracy: 0.4970 - true_positives: 320.0000 - true_negatives: 5388.0000 - val_loss: 1.1593 - val_accuracy: 0.4913 - val_true_positives: 34.0000 - val_true_negatives: 679.0000 - 452ms/epoch - 8ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 1.15931 to 1.15041, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1497 - accuracy: 0.5024 - true_positives: 322.0000 - true_negatives: 5386.0000 - val_loss: 1.1504 - val_accuracy: 0.5174 - val_true_positives: 46.0000 - val_true_negatives: 675.0000 - 489ms/epoch - 8ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 1.15041 to 1.14997, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1513 - accuracy: 0.5041 - true_positives: 319.0000 - true_negatives: 5371.0000 - val_loss: 1.1500 - val_accuracy: 0.5043 - val_true_positives: 50.0000 - val_true_negatives: 672.0000 - 488ms/epoch - 8ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 1.14997 to 1.14065, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1399 - accuracy: 0.5090 - true_positives: 313.0000 - true_negatives: 5378.0000 - val_loss: 1.1407 - val_accuracy: 0.5130 - val_true_positives: 45.0000 - val_true_negatives: 679.0000 - 486ms/epoch - 8ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 1.14065 to 1.13234, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1340 - accuracy: 0.5090 - true_positives: 365.0000 - true_negatives: 5397.0000 - val_loss: 1.1323 - val_accuracy: 0.5478 - val_true_positives: 41.0000 - val_true_negatives: 675.0000 - 485ms/epoch - 8ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 1.13234 to 1.12765, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1300 - accuracy: 0.5133 - true_positives: 340.0000 - true_negatives: 5374.0000 - val_loss: 1.1276 - val_accuracy: 0.5435 - val_true_positives: 42.0000 - val_true_negatives: 680.0000 - 491ms/epoch - 8ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 1.12765
# 58/58 - 0s - loss: 1.1198 - accuracy: 0.5182 - true_positives: 354.0000 - true_negatives: 5391.0000 - val_loss: 1.1386 - val_accuracy: 0.5348 - val_true_positives: 53.0000 - val_true_negatives: 678.0000 - 408ms/epoch - 7ms/step
# Epoch 30/300
#
# Epoch 30: val_loss did not improve from 1.12765
# 58/58 - 0s - loss: 1.1251 - accuracy: 0.5117 - true_positives: 353.0000 - true_negatives: 5383.0000 - val_loss: 1.1511 - val_accuracy: 0.5217 - val_true_positives: 45.0000 - val_true_negatives: 671.0000 - 414ms/epoch - 7ms/step
# Epoch 31/300
#
# Epoch 31: val_loss did not improve from 1.12765
# 58/58 - 0s - loss: 1.1281 - accuracy: 0.5122 - true_positives: 364.0000 - true_negatives: 5385.0000 - val_loss: 1.1292 - val_accuracy: 0.5565 - val_true_positives: 55.0000 - val_true_negatives: 667.0000 - 453ms/epoch - 8ms/step
# Epoch 32/300
#
# Epoch 32: val_loss improved from 1.12765 to 1.11585, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1232 - accuracy: 0.5079 - true_positives: 350.0000 - true_negatives: 5369.0000 - val_loss: 1.1159 - val_accuracy: 0.5348 - val_true_positives: 47.0000 - val_true_negatives: 680.0000 - 460ms/epoch - 8ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 1.11585
# 58/58 - 0s - loss: 1.1158 - accuracy: 0.5079 - true_positives: 361.0000 - true_negatives: 5372.0000 - val_loss: 1.1340 - val_accuracy: 0.5348 - val_true_positives: 56.0000 - val_true_negatives: 667.0000 - 416ms/epoch - 7ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 1.11585
# 58/58 - 0s - loss: 1.1133 - accuracy: 0.5160 - true_positives: 386.0000 - true_negatives: 5357.0000 - val_loss: 1.1281 - val_accuracy: 0.5391 - val_true_positives: 46.0000 - val_true_negatives: 674.0000 - 448ms/epoch - 8ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 1.11585
# 58/58 - 0s - loss: 1.1184 - accuracy: 0.5106 - true_positives: 385.0000 - true_negatives: 5380.0000 - val_loss: 1.1336 - val_accuracy: 0.5130 - val_true_positives: 50.0000 - val_true_negatives: 673.0000 - 411ms/epoch - 7ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 1.11585 to 1.09939, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.1124 - accuracy: 0.5187 - true_positives: 401.0000 - true_negatives: 5379.0000 - val_loss: 1.0994 - val_accuracy: 0.5435 - val_true_positives: 54.0000 - val_true_negatives: 675.0000 - 457ms/epoch - 8ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 1.09939
# 58/58 - 0s - loss: 1.0961 - accuracy: 0.5225 - true_positives: 402.0000 - true_negatives: 5364.0000 - val_loss: 1.1197 - val_accuracy: 0.5522 - val_true_positives: 53.0000 - val_true_negatives: 674.0000 - 407ms/epoch - 7ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 1.09939
# 58/58 - 0s - loss: 1.0911 - accuracy: 0.5426 - true_positives: 399.0000 - true_negatives: 5380.0000 - val_loss: 1.1120 - val_accuracy: 0.5348 - val_true_positives: 58.0000 - val_true_negatives: 668.0000 - 445ms/epoch - 8ms/step
# Epoch 39/300
#
# Epoch 39: val_loss improved from 1.09939 to 1.09532, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0937 - accuracy: 0.5421 - true_positives: 416.0000 - true_negatives: 5348.0000 - val_loss: 1.0953 - val_accuracy: 0.5478 - val_true_positives: 60.0000 - val_true_negatives: 673.0000 - 455ms/epoch - 8ms/step
# Epoch 40/300
#
# Epoch 40: val_loss improved from 1.09532 to 1.08874, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0897 - accuracy: 0.5426 - true_positives: 411.0000 - true_negatives: 5360.0000 - val_loss: 1.0887 - val_accuracy: 0.5435 - val_true_positives: 61.0000 - val_true_negatives: 679.0000 - 450ms/epoch - 8ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0940 - accuracy: 0.5323 - true_positives: 426.0000 - true_negatives: 5341.0000 - val_loss: 1.0954 - val_accuracy: 0.5391 - val_true_positives: 59.0000 - val_true_negatives: 671.0000 - 455ms/epoch - 8ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0868 - accuracy: 0.5328 - true_positives: 443.0000 - true_negatives: 5358.0000 - val_loss: 1.0968 - val_accuracy: 0.5565 - val_true_positives: 60.0000 - val_true_negatives: 672.0000 - 409ms/epoch - 7ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0762 - accuracy: 0.5355 - true_positives: 451.0000 - true_negatives: 5350.0000 - val_loss: 1.1313 - val_accuracy: 0.5217 - val_true_positives: 50.0000 - val_true_negatives: 666.0000 - 408ms/epoch - 7ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0774 - accuracy: 0.5448 - true_positives: 441.0000 - true_negatives: 5354.0000 - val_loss: 1.1060 - val_accuracy: 0.5565 - val_true_positives: 61.0000 - val_true_negatives: 664.0000 - 440ms/epoch - 8ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0789 - accuracy: 0.5317 - true_positives: 460.0000 - true_negatives: 5330.0000 - val_loss: 1.1032 - val_accuracy: 0.5522 - val_true_positives: 70.0000 - val_true_negatives: 666.0000 - 439ms/epoch - 8ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0817 - accuracy: 0.5317 - true_positives: 472.0000 - true_negatives: 5336.0000 - val_loss: 1.1045 - val_accuracy: 0.5391 - val_true_positives: 64.0000 - val_true_negatives: 668.0000 - 416ms/epoch - 7ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 1.08874
# 58/58 - 0s - loss: 1.0778 - accuracy: 0.5415 - true_positives: 464.0000 - true_negatives: 5352.0000 - val_loss: 1.0888 - val_accuracy: 0.5696 - val_true_positives: 61.0000 - val_true_negatives: 671.0000 - 418ms/epoch - 7ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 1.08874 to 1.07924, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0644 - accuracy: 0.5442 - true_positives: 485.0000 - true_negatives: 5351.0000 - val_loss: 1.0792 - val_accuracy: 0.5565 - val_true_positives: 66.0000 - val_true_negatives: 669.0000 - 453ms/epoch - 8ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 1.07924
# 58/58 - 0s - loss: 1.0598 - accuracy: 0.5524 - true_positives: 496.0000 - true_negatives: 5333.0000 - val_loss: 1.0807 - val_accuracy: 0.5565 - val_true_positives: 63.0000 - val_true_negatives: 672.0000 - 441ms/epoch - 8ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 1.07924
# 58/58 - 0s - loss: 1.0649 - accuracy: 0.5496 - true_positives: 486.0000 - true_negatives: 5346.0000 - val_loss: 1.0849 - val_accuracy: 0.5783 - val_true_positives: 69.0000 - val_true_negatives: 669.0000 - 425ms/epoch - 7ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 1.07924 to 1.07385, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0632 - accuracy: 0.5621 - true_positives: 502.0000 - true_negatives: 5354.0000 - val_loss: 1.0738 - val_accuracy: 0.5870 - val_true_positives: 66.0000 - val_true_negatives: 668.0000 - 450ms/epoch - 8ms/step
# Epoch 52/300
#
# Epoch 52: val_loss improved from 1.07385 to 1.06643, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0643 - accuracy: 0.5415 - true_positives: 495.0000 - true_negatives: 5312.0000 - val_loss: 1.0664 - val_accuracy: 0.5652 - val_true_positives: 68.0000 - val_true_negatives: 669.0000 - 446ms/epoch - 8ms/step
# Epoch 53/300
#
# Epoch 53: val_loss improved from 1.06643 to 1.06526, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0564 - accuracy: 0.5589 - true_positives: 497.0000 - true_negatives: 5327.0000 - val_loss: 1.0653 - val_accuracy: 0.6000 - val_true_positives: 73.0000 - val_true_negatives: 666.0000 - 460ms/epoch - 8ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 1.06526
# 58/58 - 0s - loss: 1.0524 - accuracy: 0.5475 - true_positives: 515.0000 - true_negatives: 5340.0000 - val_loss: 1.0915 - val_accuracy: 0.5826 - val_true_positives: 60.0000 - val_true_negatives: 670.0000 - 443ms/epoch - 8ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 1.06526
# 58/58 - 0s - loss: 1.0548 - accuracy: 0.5534 - true_positives: 523.0000 - true_negatives: 5326.0000 - val_loss: 1.0819 - val_accuracy: 0.5739 - val_true_positives: 62.0000 - val_true_negatives: 664.0000 - 415ms/epoch - 7ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 1.06526
# 58/58 - 0s - loss: 1.0527 - accuracy: 0.5502 - true_positives: 512.0000 - true_negatives: 5308.0000 - val_loss: 1.0866 - val_accuracy: 0.5870 - val_true_positives: 71.0000 - val_true_negatives: 667.0000 - 406ms/epoch - 7ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 1.06526
# 58/58 - 0s - loss: 1.0522 - accuracy: 0.5605 - true_positives: 509.0000 - true_negatives: 5308.0000 - val_loss: 1.0795 - val_accuracy: 0.5739 - val_true_positives: 68.0000 - val_true_negatives: 670.0000 - 450ms/epoch - 8ms/step
# Epoch 58/300
#
# Epoch 58: val_loss improved from 1.06526 to 1.05118, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0317 - accuracy: 0.5659 - true_positives: 555.0000 - true_negatives: 5332.0000 - val_loss: 1.0512 - val_accuracy: 0.5696 - val_true_positives: 74.0000 - val_true_negatives: 669.0000 - 452ms/epoch - 8ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 1.05118
# 58/58 - 0s - loss: 1.0424 - accuracy: 0.5600 - true_positives: 532.0000 - true_negatives: 5321.0000 - val_loss: 1.0673 - val_accuracy: 0.5826 - val_true_positives: 72.0000 - val_true_negatives: 668.0000 - 440ms/epoch - 8ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 1.05118
# 58/58 - 0s - loss: 1.0236 - accuracy: 0.5616 - true_positives: 569.0000 - true_negatives: 5334.0000 - val_loss: 1.0702 - val_accuracy: 0.5783 - val_true_positives: 68.0000 - val_true_negatives: 672.0000 - 448ms/epoch - 8ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 1.05118
# 58/58 - 0s - loss: 1.0483 - accuracy: 0.5605 - true_positives: 518.0000 - true_negatives: 5305.0000 - val_loss: 1.0592 - val_accuracy: 0.5870 - val_true_positives: 77.0000 - val_true_negatives: 666.0000 - 402ms/epoch - 7ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 1.05118
# 58/58 - 0s - loss: 1.0346 - accuracy: 0.5610 - true_positives: 565.0000 - true_negatives: 5308.0000 - val_loss: 1.0588 - val_accuracy: 0.5609 - val_true_positives: 74.0000 - val_true_negatives: 669.0000 - 457ms/epoch - 8ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 1.05118
# 58/58 - 0s - loss: 1.0287 - accuracy: 0.5714 - true_positives: 550.0000 - true_negatives: 5318.0000 - val_loss: 1.0594 - val_accuracy: 0.5478 - val_true_positives: 78.0000 - val_true_negatives: 672.0000 - 437ms/epoch - 8ms/step
# Epoch 64/300
#
# Epoch 64: val_loss improved from 1.05118 to 1.04845, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0463 - accuracy: 0.5524 - true_positives: 516.0000 - true_negatives: 5293.0000 - val_loss: 1.0485 - val_accuracy: 0.5957 - val_true_positives: 70.0000 - val_true_negatives: 670.0000 - 458ms/epoch - 8ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 1.04845
# 58/58 - 0s - loss: 1.0298 - accuracy: 0.5654 - true_positives: 585.0000 - true_negatives: 5328.0000 - val_loss: 1.0547 - val_accuracy: 0.6130 - val_true_positives: 75.0000 - val_true_negatives: 672.0000 - 447ms/epoch - 8ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 1.04845
# 58/58 - 0s - loss: 1.0088 - accuracy: 0.5719 - true_positives: 584.0000 - true_negatives: 5311.0000 - val_loss: 1.0667 - val_accuracy: 0.5957 - val_true_positives: 79.0000 - val_true_negatives: 668.0000 - 426ms/epoch - 7ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 1.04845
# 58/58 - 0s - loss: 1.0130 - accuracy: 0.5676 - true_positives: 565.0000 - true_negatives: 5318.0000 - val_loss: 1.0512 - val_accuracy: 0.5870 - val_true_positives: 76.0000 - val_true_negatives: 668.0000 - 445ms/epoch - 8ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 1.04845
# 58/58 - 0s - loss: 1.0165 - accuracy: 0.5735 - true_positives: 564.0000 - true_negatives: 5304.0000 - val_loss: 1.0495 - val_accuracy: 0.6087 - val_true_positives: 75.0000 - val_true_negatives: 669.0000 - 410ms/epoch - 7ms/step
# Epoch 69/300
#
# Epoch 69: val_loss improved from 1.04845 to 1.04450, saving model to /tmp/checkpoint.h5
# 58/58 - 0s - loss: 1.0213 - accuracy: 0.5621 - true_positives: 584.0000 - true_negatives: 5300.0000 - val_loss: 1.0445 - val_accuracy: 0.6043 - val_true_positives: 79.0000 - val_true_negatives: 667.0000 - 453ms/epoch - 8ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 1.04450
# 58/58 - 0s - loss: 1.0250 - accuracy: 0.5676 - true_positives: 587.0000 - true_negatives: 5298.0000 - val_loss: 1.0479 - val_accuracy: 0.5826 - val_true_positives: 78.0000 - val_true_negatives: 668.0000 - 446ms/epoch - 8ms/step
# Epoch 71/300
#
# Epoch 71: val_loss improved from 1.04450 to 1.02390, saving model to /tmp/checkpoint.h5
# 58/58 - 1s - loss: 0.9996 - accuracy: 0.5719 - true_positives: 631.0000 - true_negatives: 5295.0000 - val_loss: 1.0239 - val_accuracy: 0.6130 - val_true_positives: 77.0000 - val_true_negatives: 668.0000 - 507ms/epoch - 9ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 1.0027 - accuracy: 0.5708 - true_positives: 597.0000 - true_negatives: 5294.0000 - val_loss: 1.0490 - val_accuracy: 0.5913 - val_true_positives: 75.0000 - val_true_negatives: 661.0000 - 408ms/epoch - 7ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 1.0087 - accuracy: 0.5600 - true_positives: 600.0000 - true_negatives: 5284.0000 - val_loss: 1.0445 - val_accuracy: 0.5826 - val_true_positives: 80.0000 - val_true_negatives: 672.0000 - 460ms/epoch - 8ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9956 - accuracy: 0.5871 - true_positives: 622.0000 - true_negatives: 5284.0000 - val_loss: 1.0435 - val_accuracy: 0.6087 - val_true_positives: 79.0000 - val_true_negatives: 658.0000 - 408ms/epoch - 7ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9960 - accuracy: 0.5855 - true_positives: 623.0000 - true_negatives: 5304.0000 - val_loss: 1.0442 - val_accuracy: 0.5826 - val_true_positives: 80.0000 - val_true_negatives: 666.0000 - 424ms/epoch - 7ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 1.0131 - accuracy: 0.5811 - true_positives: 608.0000 - true_negatives: 5305.0000 - val_loss: 1.0498 - val_accuracy: 0.6000 - val_true_positives: 81.0000 - val_true_negatives: 662.0000 - 419ms/epoch - 7ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9961 - accuracy: 0.5708 - true_positives: 602.0000 - true_negatives: 5286.0000 - val_loss: 1.0267 - val_accuracy: 0.6217 - val_true_positives: 84.0000 - val_true_negatives: 667.0000 - 410ms/epoch - 7ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9893 - accuracy: 0.5893 - true_positives: 653.0000 - true_negatives: 5311.0000 - val_loss: 1.0468 - val_accuracy: 0.6087 - val_true_positives: 80.0000 - val_true_negatives: 663.0000 - 422ms/epoch - 7ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 1.0098 - accuracy: 0.5518 - true_positives: 623.0000 - true_negatives: 5280.0000 - val_loss: 1.0319 - val_accuracy: 0.5870 - val_true_positives: 82.0000 - val_true_negatives: 663.0000 - 406ms/epoch - 7ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9993 - accuracy: 0.5887 - true_positives: 621.0000 - true_negatives: 5282.0000 - val_loss: 1.0364 - val_accuracy: 0.6087 - val_true_positives: 78.0000 - val_true_negatives: 666.0000 - 449ms/epoch - 8ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9992 - accuracy: 0.5811 - true_positives: 645.0000 - true_negatives: 5308.0000 - val_loss: 1.0269 - val_accuracy: 0.6000 - val_true_positives: 84.0000 - val_true_negatives: 665.0000 - 411ms/epoch - 7ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9882 - accuracy: 0.6066 - true_positives: 654.0000 - true_negatives: 5301.0000 - val_loss: 1.0342 - val_accuracy: 0.6087 - val_true_positives: 83.0000 - val_true_negatives: 663.0000 - 450ms/epoch - 8ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9833 - accuracy: 0.5871 - true_positives: 647.0000 - true_negatives: 5303.0000 - val_loss: 1.0691 - val_accuracy: 0.5913 - val_true_positives: 86.0000 - val_true_negatives: 664.0000 - 441ms/epoch - 8ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9812 - accuracy: 0.5958 - true_positives: 655.0000 - true_negatives: 5303.0000 - val_loss: 1.0501 - val_accuracy: 0.6261 - val_true_positives: 83.0000 - val_true_negatives: 664.0000 - 440ms/epoch - 8ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9849 - accuracy: 0.5936 - true_positives: 633.0000 - true_negatives: 5282.0000 - val_loss: 1.0311 - val_accuracy: 0.6087 - val_true_positives: 86.0000 - val_true_negatives: 662.0000 - 418ms/epoch - 7ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9798 - accuracy: 0.5833 - true_positives: 671.0000 - true_negatives: 5298.0000 - val_loss: 1.0332 - val_accuracy: 0.6130 - val_true_positives: 84.0000 - val_true_negatives: 665.0000 - 448ms/epoch - 8ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9996 - accuracy: 0.5893 - true_positives: 646.0000 - true_negatives: 5262.0000 - val_loss: 1.0330 - val_accuracy: 0.5652 - val_true_positives: 85.0000 - val_true_negatives: 664.0000 - 451ms/epoch - 8ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9939 - accuracy: 0.5795 - true_positives: 650.0000 - true_negatives: 5271.0000 - val_loss: 1.0346 - val_accuracy: 0.6174 - val_true_positives: 85.0000 - val_true_negatives: 658.0000 - 449ms/epoch - 8ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9860 - accuracy: 0.5882 - true_positives: 653.0000 - true_negatives: 5278.0000 - val_loss: 1.0388 - val_accuracy: 0.6130 - val_true_positives: 85.0000 - val_true_negatives: 662.0000 - 451ms/epoch - 8ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9833 - accuracy: 0.5963 - true_positives: 665.0000 - true_negatives: 5302.0000 - val_loss: 1.0342 - val_accuracy: 0.5913 - val_true_positives: 87.0000 - val_true_negatives: 661.0000 - 444ms/epoch - 8ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9765 - accuracy: 0.6104 - true_positives: 674.0000 - true_negatives: 5283.0000 - val_loss: 1.0317 - val_accuracy: 0.6217 - val_true_positives: 79.0000 - val_true_negatives: 665.0000 - 451ms/epoch - 8ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9763 - accuracy: 0.5925 - true_positives: 662.0000 - true_negatives: 5285.0000 - val_loss: 1.0334 - val_accuracy: 0.6087 - val_true_positives: 84.0000 - val_true_negatives: 663.0000 - 410ms/epoch - 7ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9697 - accuracy: 0.5931 - true_positives: 680.0000 - true_negatives: 5290.0000 - val_loss: 1.0343 - val_accuracy: 0.6217 - val_true_positives: 89.0000 - val_true_negatives: 660.0000 - 408ms/epoch - 7ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 1.0010 - accuracy: 0.5724 - true_positives: 648.0000 - true_negatives: 5264.0000 - val_loss: 1.0557 - val_accuracy: 0.5870 - val_true_positives: 92.0000 - val_true_negatives: 662.0000 - 455ms/epoch - 8ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 1.02390
# 58/58 - 0s - loss: 0.9799 - accuracy: 0.5827 - true_positives: 710.0000 - true_negatives: 5278.0000 - val_loss: 1.0245 - val_accuracy: 0.6174 - val_true_positives: 86.0000 - val_true_negatives: 665.0000 - 430ms/epoch - 7ms/step
# Epoch 96/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-99552a26d7c0> in <module>()
#     117 fittedModel = model.fit(X_train, Y_train, batch_size = 32, epochs = 300,
#     118                         verbose = 2, validation_data=(X_validate, Y_validate),
# --> 119                         callbacks=[checkpointer])
#     120
#     121 # load optimal weights
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
#Block to save Model to Google Drive
from datetime import datetime
import shutil

now = datetime.now()
dt_string = now.strftime("%d-%m-%Y_%H:%M:%S")
savepath = 'drive/MyDrive/Models/Model_' + str(dt_string)  #Before Running Make folder 'Model' in Google Drive
model.save(savepath)

shutil.copy('/content/tmp/checkpoint.h5',savepath)  #checkpoint.h5 sind die weights für das gespeicherte Model

#Datetime hat nen offset von 2h, wenn du das um 15 Uhr ausführst wird es als 13 Uhr gespeichert. Zu faul zum fixen
