# %%
# !pip install mne
# !pip install tensorflow
# !pip install pyriemann
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mne in /usr/local/lib/python3.7/dist-packages (1.0.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne) (4.64.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne) (2.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne) (21.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from mne) (1.4.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from mne) (3.2.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from mne) (1.21.6)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->mne) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->mne) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyriemann in /usr/local/lib/python3.7/dist-packages (0.2.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.21.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyriemann) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyriemann) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pyriemann) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyriemann) (3.1.0)

# %%
import numpy as np
import os
import tensorflow

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.utils.viz import plot_confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

from sklearn.utils import shuffle

# %%
def EEGNet(nb_classes, Chans = 22, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    
    While the original paper used Dropout, we found that SpatialDropout2D 
    sometimes produced slightly better results for classification of ERP 
    signals. However, SpatialDropout2D significantly reduced performance 
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 
    
    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)




def EEGNet_SSVEP(nb_classes = 12, Chans = 8, Samples = 256, 
             dropoutRate = 0.5, kernLength = 256, F1 = 96, 
             D = 1, F2 = 96, dropoutType = 'Dropout'):
    """ SSVEP Variant of EEGNet, as used in [1]. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. 
      D               : number of spatial filters to learn within each temporal
                        convolution.
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.
      
      
    [1]. Waytowich, N. et. al. (2018). Compact Convolutional Neural Networks
    for Classification of Asynchronous Steady-State Visual Evoked Potentials.
    Journal of Neural Engineering vol. 15(6). 
    http://iopscience.iop.org/article/10.1088/1741-2552/aae5d8

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)



def EEGNet_old(nb_classes, Chans = 64, Samples = 128, regRate = 0.0001,
           dropoutRate = 0.25, kernels = [(2, 32), (8, 4)], strides = (2, 4)):
    """ Keras Implementation of EEGNet_v1 (https://arxiv.org/abs/1611.08024v2)

    This model is the original EEGNet model proposed on arxiv
            https://arxiv.org/abs/1611.08024v2
    
    with a few modifications: we use striding instead of max-pooling as this 
    helped slightly in classification performance while also providing a 
    computational speed-up. 
    
    Note that we no longer recommend the use of this architecture, as the new
    version of EEGNet performs much better overall and has nicer properties.
    
    Inputs:
        
        nb_classes     : total number of final categories
        Chans, Samples : number of EEG channels and samples, respectively
        regRate        : regularization rate for L1 and L2 regularizations
        dropoutRate    : dropout fraction
        kernels        : the 2nd and 3rd layer kernel dimensions (default is 
                         the [2, 32] x [8, 4] configuration)
        strides        : the stride size (note that this replaces the max-pool
                         used in the original paper)
    
    """

    # start the model
    input_main   = Input((Chans, Samples))
    layer1       = Conv2D(16, (Chans, 1), input_shape=(Chans, Samples, 1),
                                 kernel_regularizer = l1_l2(l1=regRate, l2=regRate))(input_main)
    layer1       = BatchNormalization()(layer1)
    layer1       = Activation('elu')(layer1)
    layer1       = Dropout(dropoutRate)(layer1)
    
    permute_dims = 2, 1, 3
    permute1     = Permute(permute_dims)(layer1)
    
    layer2       = Conv2D(4, kernels[0], padding = 'same', 
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(permute1)
    layer2       = BatchNormalization()(layer2)
    layer2       = Activation('elu')(layer2)
    layer2       = Dropout(dropoutRate)(layer2)
    
    layer3       = Conv2D(4, kernels[1], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(layer2)
    layer3       = BatchNormalization()(layer3)
    layer3       = Activation('elu')(layer3)
    layer3       = Dropout(dropoutRate)(layer3)
    
    flatten      = Flatten(name = 'flatten')(layer3)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)



def DeepConvNet(nb_classes, Chans = 64, Samples = 256,
                dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.
    
    This implementation assumes the input is a 2-second EEG signal sampled at 
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference. 
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10
    
    Note that this implementation has not been verified by the original 
    authors. 
    
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)


# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 64, Samples = 128, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path_string = '/content/drive/MyDrive/BCICIV_2a_gdf/'

file_path_string = folder_path_string + "A01T.gdf"
evaluation_path_string = folder_path_string + "A01T.evt"

filenames = os.listdir(folder_path_string)
print(filenames)
raws = []

'''filenames = [ "A01T.gdf", 'A02T.gdf', 'A03T.gdf', 'A05T.gdf', 'A06T.gdf', 'A07T.gdf', 'A08T.gdf', 'A09T.gdf']
raws = []

for filename in filenames:
    path = folder_path_string + filename
    raws.append(mne.io.read_raw_gdf(path))'''
# Out:
# ['A01T.gdf', 'A01E.gdf', 'A02T.gdf', 'A02E.gdf', 'A03T.gdf', 'A03E.gdf', 'A04T.gdf', 'A04E.gdf', 'A05T.gdf', 'A05E.gdf', 'A06T.gdf', 'A06E.gdf', 'A07T.gdf', 'A07E.gdf', 'A08T.gdf', 'A08E.gdf', 'A09T.gdf', 'A09E.gdf']
# 'filenames = [ "A01T.gdf", \'A02T.gdf\', \'A03T.gdf\', \'A05T.gdf\', \'A06T.gdf\', \'A07T.gdf\', \'A08T.gdf\', \'A09T.gdf\']\nraws = []\n\nfor filename in filenames:\n    path = folder_path_string + filename\n    raws.append(mne.io.read_raw_gdf(path))'

# %%
#set seed
tensorflow.random.set_seed(1234)

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
#data_path = sample.data_path()

# Set parameters and read data
#raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
raw_fname = file_path_string
#event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
event_fname = evaluation_path_string
tmin, tmax = -0., 1
#event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)
#event_id = dict(hand_left=1, hand_right=2, foot=3, tongue=4)

# Setup for reading the raw data
#raw = io.Raw(raw_fname, preload=True, verbose=False)
raw = mne.io.read_raw_gdf(raw_fname)
raw.load_data()


#new filter
#iir_params = dict(order=3, ftype='butter', sfreq = 250, output='sos', btype='highpass')
#raw.filter(2,None, method='iir', iir_params=iir_params) 


#original filter
raw.filter(2, None, method='iir')  # replace baselining with high-pass 
#raw.filter(2, None, method='fir')
events, event_ids = mne.events_from_annotations(raw)
#print("event_id ", event_id)
event_id = events[1]
print("event_id ",event_id)

#raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False)

# Read epochs
stims =[value for key, value in event_ids.items() if key in ('769','770','771','772')]
epochs = mne.Epochs(raw, events, stims, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
channels_to_remove = ['EOG-left', 'EOG-central', 'EOG-right']
epochs = epochs.drop_channels(channels_to_remove)
labels = epochs.events[:, -1]
print(epochs)

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels
y[y == 7] = 0
y[y == 8] = 1
y[y == 9] = 2
y[y == 10] = 3

kernels, chans, samples = 1, X.shape[1], X.shape[2]

# take 50/25/25 percent of the data to train/validate/test

train_idx = round(X.shape[0] * 0.5)
test_idx = round(X.shape[0] * 0.75)
#X, y = shuffle(X, y, random_state=0) 

X_train      = X[0:train_idx,]
Y_train      = y[0:train_idx]
X_validate   = X[train_idx:test_idx,]
Y_validate   = y[train_idx:test_idx]
X_test       = X[test_idx:,]
Y_test       = y[test_idx:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
y_unique = np.unique(y)
num_classes = len(y_unique)
Y_train      = np_utils.to_categorical(Y_train-1, num_classes=num_classes)
Y_validate   = np_utils.to_categorical(Y_validate-1, num_classes=num_classes)
Y_test       = np_utils.to_categorical(Y_test-1, num_classes=num_classes)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)

print("X.Shape", X.shape)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
print("y.Shape", y.shape)
print('y_train shape:', Y_train.shape)
print('y_test shape:', Y_test.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples,              ####################################### Change Model here
               dropoutRate = 0.5, kernLength = 128, F1 = 16, D = 2, F2 = 16,   #change kernel, F1, F2 etc.
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy', 'TruePositives', 'TrueNegatives'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='tmp/checkpoint.h5', verbose=1,
                               save_best_only=True)

#fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
#                        verbose = 2, validation_data=(X_validate, Y_validate),
#                        callbacks=[checkpointer], class_weight = class_weights)

fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 100, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])

# load optimal weights
model.load_weights('tmp/checkpoint.h5')

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/BCICIV_2a_gdf/A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# /usr/local/lib/python3.7/dist-packages/mne/io/edf/edf.py:1123: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# /usr/lib/python3.7/contextlib.py:119: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# event_id  [0 0 3]
# <Epochs |  288 events (all good), 0 - 1 sec, baseline off, ~12.2 MB, data loaded,
#  '7': 72
#  '8': 72
#  '9': 72
#  '10': 72>
# X.Shape (288, 22, 251)
# X_train shape: (144, 22, 251, 1)
# X_test shape: (72, 22, 251, 1)
# y.Shape (288,)
# y_train shape: (144, 4)
# y_test shape: (72, 4)
# 144 train samples
# 72 test samples
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.38658, saving model to tmp/checkpoint.h5
# 9/9 - 1s - loss: 1.3882 - accuracy: 0.2708 - true_positives: 3.0000 - true_negatives: 428.0000 - val_loss: 1.3866 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 1s/epoch - 158ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.38658 to 1.38639, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3853 - accuracy: 0.2361 - true_positives: 0.0000e+00 - true_negatives: 432.0000 - val_loss: 1.3864 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 142ms/epoch - 16ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.38639 to 1.38631, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3605 - accuracy: 0.3611 - true_positives: 0.0000e+00 - true_negatives: 432.0000 - val_loss: 1.3863 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 147ms/epoch - 16ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.38631 to 1.38614, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3407 - accuracy: 0.3889 - true_positives: 0.0000e+00 - true_negatives: 432.0000 - val_loss: 1.3861 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 146ms/epoch - 16ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.3404 - accuracy: 0.3403 - true_positives: 0.0000e+00 - true_negatives: 432.0000 - val_loss: 1.3863 - val_accuracy: 0.1944 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 108ms/epoch - 12ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.3226 - accuracy: 0.3681 - true_positives: 0.0000e+00 - true_negatives: 432.0000 - val_loss: 1.3863 - val_accuracy: 0.3056 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 109ms/epoch - 12ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.3022 - accuracy: 0.4375 - true_positives: 0.0000e+00 - true_negatives: 432.0000 - val_loss: 1.3862 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 100ms/epoch - 11ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.2576 - accuracy: 0.4861 - true_positives: 1.0000 - true_negatives: 432.0000 - val_loss: 1.3863 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 103ms/epoch - 11ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.2653 - accuracy: 0.4653 - true_positives: 1.0000 - true_negatives: 432.0000 - val_loss: 1.3865 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 103ms/epoch - 11ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.2528 - accuracy: 0.4861 - true_positives: 0.0000e+00 - true_negatives: 431.0000 - val_loss: 1.3865 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 103ms/epoch - 11ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.2116 - accuracy: 0.5208 - true_positives: 3.0000 - true_negatives: 432.0000 - val_loss: 1.3866 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 102ms/epoch - 11ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.2146 - accuracy: 0.5208 - true_positives: 3.0000 - true_negatives: 432.0000 - val_loss: 1.3866 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 100ms/epoch - 11ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1985 - accuracy: 0.5694 - true_positives: 4.0000 - true_negatives: 429.0000 - val_loss: 1.3867 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 115ms/epoch - 13ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1919 - accuracy: 0.4861 - true_positives: 4.0000 - true_negatives: 430.0000 - val_loss: 1.3866 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 101ms/epoch - 11ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1627 - accuracy: 0.5278 - true_positives: 4.0000 - true_negatives: 432.0000 - val_loss: 1.3867 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 109ms/epoch - 12ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1769 - accuracy: 0.5139 - true_positives: 7.0000 - true_negatives: 431.0000 - val_loss: 1.3867 - val_accuracy: 0.2778 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 102ms/epoch - 11ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1680 - accuracy: 0.5486 - true_positives: 9.0000 - true_negatives: 432.0000 - val_loss: 1.3865 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 99ms/epoch - 11ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1471 - accuracy: 0.5764 - true_positives: 7.0000 - true_negatives: 432.0000 - val_loss: 1.3865 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 104ms/epoch - 12ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1429 - accuracy: 0.5625 - true_positives: 8.0000 - true_negatives: 432.0000 - val_loss: 1.3863 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 96ms/epoch - 11ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1261 - accuracy: 0.5278 - true_positives: 9.0000 - true_negatives: 431.0000 - val_loss: 1.3864 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 104ms/epoch - 12ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1323 - accuracy: 0.5556 - true_positives: 10.0000 - true_negatives: 430.0000 - val_loss: 1.3866 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 104ms/epoch - 12ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1190 - accuracy: 0.6181 - true_positives: 16.0000 - true_negatives: 429.0000 - val_loss: 1.3863 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 101ms/epoch - 11ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 1.38614
# 9/9 - 0s - loss: 1.1023 - accuracy: 0.5972 - true_positives: 12.0000 - true_negatives: 430.0000 - val_loss: 1.3863 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 101ms/epoch - 11ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 1.38614 to 1.38612, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1302 - accuracy: 0.5903 - true_positives: 11.0000 - true_negatives: 430.0000 - val_loss: 1.3861 - val_accuracy: 0.2361 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 154ms/epoch - 17ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 1.38612
# 9/9 - 0s - loss: 1.1046 - accuracy: 0.5972 - true_positives: 9.0000 - true_negatives: 432.0000 - val_loss: 1.3861 - val_accuracy: 0.2361 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 102ms/epoch - 11ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 1.38612
# 9/9 - 0s - loss: 1.0840 - accuracy: 0.6389 - true_positives: 14.0000 - true_negatives: 431.0000 - val_loss: 1.3864 - val_accuracy: 0.2361 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 109ms/epoch - 12ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 1.38612 to 1.38609, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0866 - accuracy: 0.5764 - true_positives: 17.0000 - true_negatives: 430.0000 - val_loss: 1.3861 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 187ms/epoch - 21ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 1.38609 to 1.38572, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0994 - accuracy: 0.5903 - true_positives: 13.0000 - true_negatives: 430.0000 - val_loss: 1.3857 - val_accuracy: 0.3056 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 145ms/epoch - 16ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 1.38572 to 1.38503, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0896 - accuracy: 0.5903 - true_positives: 19.0000 - true_negatives: 428.0000 - val_loss: 1.3850 - val_accuracy: 0.2778 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 146ms/epoch - 16ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0594 - accuracy: 0.5903 - true_positives: 27.0000 - true_negatives: 430.0000 - val_loss: 1.3854 - val_accuracy: 0.2083 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 105ms/epoch - 12ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0696 - accuracy: 0.6111 - true_positives: 19.0000 - true_negatives: 426.0000 - val_loss: 1.3852 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 110ms/epoch - 12ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0785 - accuracy: 0.5903 - true_positives: 19.0000 - true_negatives: 430.0000 - val_loss: 1.3853 - val_accuracy: 0.2361 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 98ms/epoch - 11ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0642 - accuracy: 0.6111 - true_positives: 20.0000 - true_negatives: 431.0000 - val_loss: 1.3854 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 99ms/epoch - 11ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0688 - accuracy: 0.6389 - true_positives: 21.0000 - true_negatives: 428.0000 - val_loss: 1.3853 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 99ms/epoch - 11ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0585 - accuracy: 0.6250 - true_positives: 22.0000 - true_negatives: 432.0000 - val_loss: 1.3856 - val_accuracy: 0.3056 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 100ms/epoch - 11ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0278 - accuracy: 0.6319 - true_positives: 22.0000 - true_negatives: 430.0000 - val_loss: 1.3858 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 105ms/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0526 - accuracy: 0.6250 - true_positives: 18.0000 - true_negatives: 430.0000 - val_loss: 1.3864 - val_accuracy: 0.2778 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 106ms/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0418 - accuracy: 0.5972 - true_positives: 26.0000 - true_negatives: 429.0000 - val_loss: 1.3850 - val_accuracy: 0.2361 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 111ms/epoch - 12ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0290 - accuracy: 0.6528 - true_positives: 26.0000 - true_negatives: 429.0000 - val_loss: 1.3855 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 142ms/epoch - 16ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 1.38503
# 9/9 - 0s - loss: 1.0184 - accuracy: 0.6597 - true_positives: 29.0000 - true_negatives: 431.0000 - val_loss: 1.3851 - val_accuracy: 0.2500 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 110ms/epoch - 12ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 1.38503 to 1.38489, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0162 - accuracy: 0.6181 - true_positives: 24.0000 - true_negatives: 430.0000 - val_loss: 1.3849 - val_accuracy: 0.2222 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 148ms/epoch - 16ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 1.0239 - accuracy: 0.6181 - true_positives: 30.0000 - true_negatives: 427.0000 - val_loss: 1.3849 - val_accuracy: 0.2778 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 104ms/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9981 - accuracy: 0.7153 - true_positives: 27.0000 - true_negatives: 430.0000 - val_loss: 1.3853 - val_accuracy: 0.2361 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 104ms/epoch - 12ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9667 - accuracy: 0.7014 - true_positives: 28.0000 - true_negatives: 429.0000 - val_loss: 1.3865 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 106ms/epoch - 12ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9703 - accuracy: 0.6667 - true_positives: 33.0000 - true_negatives: 429.0000 - val_loss: 1.3867 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 100ms/epoch - 11ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9769 - accuracy: 0.6597 - true_positives: 38.0000 - true_negatives: 429.0000 - val_loss: 1.3894 - val_accuracy: 0.3056 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 103ms/epoch - 11ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9428 - accuracy: 0.7569 - true_positives: 38.0000 - true_negatives: 431.0000 - val_loss: 1.3901 - val_accuracy: 0.3056 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 99ms/epoch - 11ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9406 - accuracy: 0.7083 - true_positives: 35.0000 - true_negatives: 432.0000 - val_loss: 1.3907 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 145ms/epoch - 16ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9615 - accuracy: 0.6875 - true_positives: 31.0000 - true_negatives: 431.0000 - val_loss: 1.3952 - val_accuracy: 0.3194 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 109ms/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9761 - accuracy: 0.6944 - true_positives: 32.0000 - true_negatives: 428.0000 - val_loss: 1.3924 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 104ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9069 - accuracy: 0.7639 - true_positives: 36.0000 - true_negatives: 430.0000 - val_loss: 1.3915 - val_accuracy: 0.2917 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 95ms/epoch - 11ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9586 - accuracy: 0.6597 - true_positives: 40.0000 - true_negatives: 431.0000 - val_loss: 1.3965 - val_accuracy: 0.3194 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 101ms/epoch - 11ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9342 - accuracy: 0.6944 - true_positives: 39.0000 - true_negatives: 427.0000 - val_loss: 1.4003 - val_accuracy: 0.3472 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 101ms/epoch - 11ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9111 - accuracy: 0.7153 - true_positives: 40.0000 - true_negatives: 428.0000 - val_loss: 1.4058 - val_accuracy: 0.3333 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 99ms/epoch - 11ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8999 - accuracy: 0.7014 - true_positives: 51.0000 - true_negatives: 429.0000 - val_loss: 1.4132 - val_accuracy: 0.3611 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 105ms/epoch - 12ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9249 - accuracy: 0.7014 - true_positives: 44.0000 - true_negatives: 430.0000 - val_loss: 1.4231 - val_accuracy: 0.3750 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 102ms/epoch - 11ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.9177 - accuracy: 0.7083 - true_positives: 38.0000 - true_negatives: 429.0000 - val_loss: 1.4287 - val_accuracy: 0.3333 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 106ms/epoch - 12ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8981 - accuracy: 0.7431 - true_positives: 46.0000 - true_negatives: 429.0000 - val_loss: 1.4279 - val_accuracy: 0.3472 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - 105ms/epoch - 12ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8913 - accuracy: 0.7431 - true_positives: 46.0000 - true_negatives: 426.0000 - val_loss: 1.4301 - val_accuracy: 0.3750 - val_true_positives: 0.0000e+00 - val_true_negatives: 215.0000 - 99ms/epoch - 11ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8716 - accuracy: 0.7222 - true_positives: 48.0000 - true_negatives: 431.0000 - val_loss: 1.4276 - val_accuracy: 0.3750 - val_true_positives: 1.0000 - val_true_negatives: 215.0000 - 97ms/epoch - 11ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8854 - accuracy: 0.7292 - true_positives: 58.0000 - true_negatives: 427.0000 - val_loss: 1.4311 - val_accuracy: 0.3333 - val_true_positives: 2.0000 - val_true_negatives: 215.0000 - 108ms/epoch - 12ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8750 - accuracy: 0.7361 - true_positives: 52.0000 - true_negatives: 427.0000 - val_loss: 1.4108 - val_accuracy: 0.3472 - val_true_positives: 2.0000 - val_true_negatives: 215.0000 - 114ms/epoch - 13ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8360 - accuracy: 0.8194 - true_positives: 53.0000 - true_negatives: 430.0000 - val_loss: 1.3968 - val_accuracy: 0.3194 - val_true_positives: 3.0000 - val_true_negatives: 215.0000 - 99ms/epoch - 11ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 1.38489
# 9/9 - 0s - loss: 0.8541 - accuracy: 0.7292 - true_positives: 55.0000 - true_negatives: 429.0000 - val_loss: 1.3907 - val_accuracy: 0.3333 - val_true_positives: 0.0000e+00 - val_true_negatives: 215.0000 - 101ms/epoch - 11ms/step
# Epoch 65/100
#
# Epoch 65: val_loss improved from 1.38489 to 1.38085, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8568 - accuracy: 0.7639 - true_positives: 50.0000 - true_negatives: 429.0000 - val_loss: 1.3809 - val_accuracy: 0.3194 - val_true_positives: 2.0000 - val_true_negatives: 215.0000 - 143ms/epoch - 16ms/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 1.38085 to 1.36200, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8403 - accuracy: 0.7500 - true_positives: 58.0000 - true_negatives: 429.0000 - val_loss: 1.3620 - val_accuracy: 0.3194 - val_true_positives: 2.0000 - val_true_negatives: 214.0000 - 150ms/epoch - 17ms/step
# Epoch 67/100
#
# Epoch 67: val_loss improved from 1.36200 to 1.35091, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8547 - accuracy: 0.7708 - true_positives: 51.0000 - true_negatives: 429.0000 - val_loss: 1.3509 - val_accuracy: 0.3333 - val_true_positives: 5.0000 - val_true_negatives: 215.0000 - 146ms/epoch - 16ms/step
# Epoch 68/100
#
# Epoch 68: val_loss improved from 1.35091 to 1.32919, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8460 - accuracy: 0.7569 - true_positives: 53.0000 - true_negatives: 427.0000 - val_loss: 1.3292 - val_accuracy: 0.3611 - val_true_positives: 5.0000 - val_true_negatives: 214.0000 - 142ms/epoch - 16ms/step
# Epoch 69/100
#
# Epoch 69: val_loss improved from 1.32919 to 1.30672, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8584 - accuracy: 0.7500 - true_positives: 59.0000 - true_negatives: 428.0000 - val_loss: 1.3067 - val_accuracy: 0.3611 - val_true_positives: 6.0000 - val_true_negatives: 214.0000 - 145ms/epoch - 16ms/step
# Epoch 70/100
#
# Epoch 70: val_loss improved from 1.30672 to 1.28449, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8475 - accuracy: 0.7569 - true_positives: 51.0000 - true_negatives: 429.0000 - val_loss: 1.2845 - val_accuracy: 0.3611 - val_true_positives: 5.0000 - val_true_negatives: 215.0000 - 146ms/epoch - 16ms/step
# Epoch 71/100
#
# Epoch 71: val_loss improved from 1.28449 to 1.28248, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8109 - accuracy: 0.7639 - true_positives: 59.0000 - true_negatives: 428.0000 - val_loss: 1.2825 - val_accuracy: 0.3750 - val_true_positives: 6.0000 - val_true_negatives: 214.0000 - 152ms/epoch - 17ms/step
# Epoch 72/100
#
# Epoch 72: val_loss improved from 1.28248 to 1.26378, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7939 - accuracy: 0.7708 - true_positives: 66.0000 - true_negatives: 427.0000 - val_loss: 1.2638 - val_accuracy: 0.3750 - val_true_positives: 5.0000 - val_true_negatives: 213.0000 - 153ms/epoch - 17ms/step
# Epoch 73/100
#
# Epoch 73: val_loss improved from 1.26378 to 1.25106, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8433 - accuracy: 0.7431 - true_positives: 59.0000 - true_negatives: 428.0000 - val_loss: 1.2511 - val_accuracy: 0.4167 - val_true_positives: 7.0000 - val_true_negatives: 213.0000 - 154ms/epoch - 17ms/step
# Epoch 74/100
#
# Epoch 74: val_loss improved from 1.25106 to 1.24383, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8036 - accuracy: 0.8056 - true_positives: 69.0000 - true_negatives: 429.0000 - val_loss: 1.2438 - val_accuracy: 0.4167 - val_true_positives: 7.0000 - val_true_negatives: 214.0000 - 146ms/epoch - 16ms/step
# Epoch 75/100
#
# Epoch 75: val_loss improved from 1.24383 to 1.21561, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8255 - accuracy: 0.7639 - true_positives: 65.0000 - true_negatives: 427.0000 - val_loss: 1.2156 - val_accuracy: 0.4167 - val_true_positives: 7.0000 - val_true_negatives: 215.0000 - 149ms/epoch - 17ms/step
# Epoch 76/100
#
# Epoch 76: val_loss improved from 1.21561 to 1.19099, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8150 - accuracy: 0.7431 - true_positives: 59.0000 - true_negatives: 427.0000 - val_loss: 1.1910 - val_accuracy: 0.5000 - val_true_positives: 7.0000 - val_true_negatives: 213.0000 - 148ms/epoch - 16ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 1.19099 to 1.18269, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7733 - accuracy: 0.7778 - true_positives: 69.0000 - true_negatives: 426.0000 - val_loss: 1.1827 - val_accuracy: 0.4583 - val_true_positives: 8.0000 - val_true_negatives: 211.0000 - 148ms/epoch - 16ms/step
# Epoch 78/100
#
# Epoch 78: val_loss improved from 1.18269 to 1.14780, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8194 - accuracy: 0.7153 - true_positives: 62.0000 - true_negatives: 426.0000 - val_loss: 1.1478 - val_accuracy: 0.5000 - val_true_positives: 8.0000 - val_true_negatives: 210.0000 - 189ms/epoch - 21ms/step
# Epoch 79/100
#
# Epoch 79: val_loss improved from 1.14780 to 1.13662, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8181 - accuracy: 0.7569 - true_positives: 61.0000 - true_negatives: 430.0000 - val_loss: 1.1366 - val_accuracy: 0.5417 - val_true_positives: 10.0000 - val_true_negatives: 208.0000 - 155ms/epoch - 17ms/step
# Epoch 80/100
#
# Epoch 80: val_loss improved from 1.13662 to 1.13218, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8028 - accuracy: 0.7778 - true_positives: 59.0000 - true_negatives: 430.0000 - val_loss: 1.1322 - val_accuracy: 0.5000 - val_true_positives: 8.0000 - val_true_negatives: 207.0000 - 142ms/epoch - 16ms/step
# Epoch 81/100
#
# Epoch 81: val_loss improved from 1.13218 to 1.10906, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7876 - accuracy: 0.7847 - true_positives: 67.0000 - true_negatives: 431.0000 - val_loss: 1.1091 - val_accuracy: 0.5556 - val_true_positives: 11.0000 - val_true_negatives: 207.0000 - 144ms/epoch - 16ms/step
# Epoch 82/100
#
# Epoch 82: val_loss improved from 1.10906 to 1.10205, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7779 - accuracy: 0.7778 - true_positives: 68.0000 - true_negatives: 429.0000 - val_loss: 1.1020 - val_accuracy: 0.5417 - val_true_positives: 13.0000 - val_true_negatives: 208.0000 - 147ms/epoch - 16ms/step
# Epoch 83/100
#
# Epoch 83: val_loss improved from 1.10205 to 1.09986, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7725 - accuracy: 0.7917 - true_positives: 66.0000 - true_negatives: 426.0000 - val_loss: 1.0999 - val_accuracy: 0.4583 - val_true_positives: 10.0000 - val_true_negatives: 209.0000 - 140ms/epoch - 16ms/step
# Epoch 84/100
#
# Epoch 84: val_loss improved from 1.09986 to 1.08281, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7552 - accuracy: 0.7639 - true_positives: 73.0000 - true_negatives: 430.0000 - val_loss: 1.0828 - val_accuracy: 0.5417 - val_true_positives: 10.0000 - val_true_negatives: 210.0000 - 145ms/epoch - 16ms/step
# Epoch 85/100
#
# Epoch 85: val_loss improved from 1.08281 to 1.07330, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7450 - accuracy: 0.8333 - true_positives: 74.0000 - true_negatives: 426.0000 - val_loss: 1.0733 - val_accuracy: 0.5694 - val_true_positives: 10.0000 - val_true_negatives: 210.0000 - 153ms/epoch - 17ms/step
# Epoch 86/100
#
# Epoch 86: val_loss improved from 1.07330 to 1.06862, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7830 - accuracy: 0.8056 - true_positives: 68.0000 - true_negatives: 426.0000 - val_loss: 1.0686 - val_accuracy: 0.5278 - val_true_positives: 11.0000 - val_true_negatives: 209.0000 - 140ms/epoch - 16ms/step
# Epoch 87/100
#
# Epoch 87: val_loss improved from 1.06862 to 1.04749, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7608 - accuracy: 0.7708 - true_positives: 71.0000 - true_negatives: 426.0000 - val_loss: 1.0475 - val_accuracy: 0.6111 - val_true_positives: 12.0000 - val_true_negatives: 210.0000 - 146ms/epoch - 16ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 1.04749
# 9/9 - 0s - loss: 0.7869 - accuracy: 0.7500 - true_positives: 72.0000 - true_negatives: 424.0000 - val_loss: 1.0706 - val_accuracy: 0.5139 - val_true_positives: 13.0000 - val_true_negatives: 206.0000 - 107ms/epoch - 12ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 1.04749
# 9/9 - 0s - loss: 0.7495 - accuracy: 0.7639 - true_positives: 65.0000 - true_negatives: 425.0000 - val_loss: 1.0483 - val_accuracy: 0.5833 - val_true_positives: 17.0000 - val_true_negatives: 210.0000 - 105ms/epoch - 12ms/step
# Epoch 90/100
#
# Epoch 90: val_loss improved from 1.04749 to 1.03280, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7318 - accuracy: 0.8403 - true_positives: 76.0000 - true_negatives: 428.0000 - val_loss: 1.0328 - val_accuracy: 0.5972 - val_true_positives: 17.0000 - val_true_negatives: 209.0000 - 145ms/epoch - 16ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 1.03280
# 9/9 - 0s - loss: 0.6956 - accuracy: 0.8889 - true_positives: 82.0000 - true_negatives: 428.0000 - val_loss: 1.0482 - val_accuracy: 0.5694 - val_true_positives: 17.0000 - val_true_negatives: 208.0000 - 108ms/epoch - 12ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 1.03280
# 9/9 - 0s - loss: 0.7409 - accuracy: 0.8056 - true_positives: 77.0000 - true_negatives: 428.0000 - val_loss: 1.0332 - val_accuracy: 0.5694 - val_true_positives: 20.0000 - val_true_negatives: 208.0000 - 104ms/epoch - 12ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 1.03280
# 9/9 - 0s - loss: 0.7673 - accuracy: 0.7917 - true_positives: 64.0000 - true_negatives: 427.0000 - val_loss: 1.0438 - val_accuracy: 0.5833 - val_true_positives: 16.0000 - val_true_negatives: 209.0000 - 108ms/epoch - 12ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 1.03280
# 9/9 - 0s - loss: 0.7344 - accuracy: 0.8125 - true_positives: 80.0000 - true_negatives: 431.0000 - val_loss: 1.0407 - val_accuracy: 0.5278 - val_true_positives: 18.0000 - val_true_negatives: 209.0000 - 99ms/epoch - 11ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 1.03280
# 9/9 - 0s - loss: 0.7354 - accuracy: 0.7708 - true_positives: 81.0000 - true_negatives: 425.0000 - val_loss: 1.0345 - val_accuracy: 0.5694 - val_true_positives: 20.0000 - val_true_negatives: 209.0000 - 100ms/epoch - 11ms/step
# Epoch 96/100
#
# Epoch 96: val_loss improved from 1.03280 to 1.00894, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7184 - accuracy: 0.7847 - true_positives: 77.0000 - true_negatives: 428.0000 - val_loss: 1.0089 - val_accuracy: 0.5972 - val_true_positives: 22.0000 - val_true_negatives: 210.0000 - 140ms/epoch - 16ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 1.00894
# 9/9 - 0s - loss: 0.7151 - accuracy: 0.8125 - true_positives: 76.0000 - true_negatives: 427.0000 - val_loss: 1.0102 - val_accuracy: 0.5556 - val_true_positives: 24.0000 - val_true_negatives: 209.0000 - 107ms/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: val_loss improved from 1.00894 to 0.99483, saving model to tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7180 - accuracy: 0.8194 - true_positives: 77.0000 - true_negatives: 429.0000 - val_loss: 0.9948 - val_accuracy: 0.5972 - val_true_positives: 23.0000 - val_true_negatives: 209.0000 - 180ms/epoch - 20ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.99483
# 9/9 - 0s - loss: 0.7617 - accuracy: 0.7778 - true_positives: 68.0000 - true_negatives: 428.0000 - val_loss: 1.0168 - val_accuracy: 0.5417 - val_true_positives: 21.0000 - val_true_negatives: 210.0000 - 198ms/epoch - 22ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.99483
# 9/9 - 0s - loss: 0.7421 - accuracy: 0.7847 - true_positives: 72.0000 - true_negatives: 424.0000 - val_loss: 0.9976 - val_accuracy: 0.5833 - val_true_positives: 24.0000 - val_true_negatives: 208.0000 - 176ms/epoch - 20ms/step
# Classification accuracy: 0.638889

# %%
#Block to save Model to Google Drive
from datetime import datetime
import shutil

now = datetime.now()
dt_string = now.strftime("%d-%m-%Y_%H:%M:%S")
savepath = 'drive/MyDrive/Models/Model_' + str(dt_string)  #Before Running Make folder 'Model' in Google Drive
model.save(savepath)

shutil.copy('/content/tmp/checkpoint.h5',savepath)  #checkpoint.h5 sind die weights für das gespeicherte Model

#Datetime hat nen offset von 2h, wenn du das um 15 Uhr ausführst wird es als 13 Uhr gespeichert. Zu faul zum fixen
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/Models/Model_14-06-2022_13:17:01/assets
# 'drive/MyDrive/Models/Model_14-06-2022_13:17:01/checkpoint.h5'
